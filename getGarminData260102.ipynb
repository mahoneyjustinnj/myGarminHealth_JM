# %% [markdown]
# <a href="https://colab.research.google.com/github/mahoneyjustinnj/myGarminHealth_JM/blob/main/getGarminData260102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#! pip install garminconnect

# %%
# command line itself, is written into the file.
# %%writefile cods.py
EMAIL = "???"
PASSWORD="???"
# Out:
# Overwriting cods.py

# %%
#!pip install garminconnect

# This cell uses the `%%writefile` magic command to create a file named `cods.py`
# in the current working directory. The content of this cell, excluding the magic
# command line itself, is written into the file.

from cods import PASSWORD, EMAIL
# print(EMAIL)
# print(PASSWORD)
import garminconnect
#from getpass import getpass
import os
# Define the path you want to set as your working directory
path = "/content"
# Set the working directory
os.chdir(path)
# Confirm it's set correctly
print("Current working directory:", os.getcwd())

# print(EMAIL)
# print(PASSWORD)

# run locally or in Colab
# pip install garminconnect garth pandas
from datetime import date, timedelta
import pandas as pd
from garminconnect import Garmin

# Login
g = Garmin(email=EMAIL, password=PASSWORD)
g.login()
#check if login succeeds
print(g.garth.profile)

from datetime import date, timedelta
import pandas as pd

# Define the start and end dates
start_date = date(2025, 8, 20)
end_date = date.today()

# Initialize a list to store all daily summaries
all_summaries = []

# Loop through each date
current_date = start_date
while current_date <= end_date:
    try:
        # Get heart rate summary
        hr_summary = g.get_heart_rates(current_date.isoformat())

        # Get HRV data
        hrv_data = g.get_hrv_data(current_date.isoformat())

        # Get respiration data
        respiration_data = g.get_respiration_data(current_date.isoformat())

	# Get respiration data
        sleep_data = g.get_sleep_data(current_date.isoformat())

        # Combine all data into one dictionary
        combined = {
            "summaryDate": current_date.isoformat(),
            **hr_summary,
            **hrv_data,
            **respiration_data,
            **sleep_data
        }

        # Append to the list
        all_summaries.append(combined)

    except Exception as e:
        print(f"Error fetching {current_date}: {e}")

    current_date += timedelta(days=1)

# Convert to DataFrame
df = pd.DataFrame(all_summaries)

# Save to CSV
df.to_csv("garmin_combined_summaries_from_2026-01-22.csv", index=False)
# Out:
# Current working directory: /content
# ...

# %% [markdown]
# #Push Garmin data to github

# %%
# Install PyGithub library
#!pip install PyGithub

# %%
# Import necessary libraries
from google.colab import userdata
from github import Github
import pandas as pd
TOKEN = userdata.get('GITHUB_TOKEN')
g = Github(TOKEN)
# Out:
# /tmp/ipython-input-1616460730.py:6: DeprecationWarning: Argument login_or_token is deprecated, please use auth=github.Auth.Token(...) instead
#   g = Github(TOKEN)

# %%
# Import necessary libraries
# from github import Github
# import pandas as pd

# Authenticate with GitHub using your personal access token
#g = Github("YOUR_GITHUB_TOKEN")

# Get your repository
repo = g.get_user().get_repo("myGarminHealth_JM")

# Read your CSV file from /content folder
df = pd.read_csv("/content/garmin_combined_summaries_from_2026-01-22.csv")

# Convert dataframe to CSV string
csv_content = df.to_csv(index=False)

# Define file path
file_path = "rawGarminData.csv"

# Check if the file exists in the repository
try:
    contents = repo.get_contents(file_path)
    # If file exists, update it
    repo.update_file(
        path=file_path,
        message="Update raw Garmin health data",  # Commit message for update
        content=csv_content,
        sha=contents.sha
    )
    print(f"File updated successfully in {repo.full_name}")
except Exception as e:
    # If file does not exist (or other error), create it
    if "Not Found" in str(e):
        repo.create_file(
            path=file_path,  # Path in repo where file will be saved
            message="Add raw Garmin health data",  # Commit message for creation
            content=csv_content
        )
        print(f"File created successfully in {repo.full_name}")
    else:
        print(f"An unexpected error occurred: {e}")
# Out:
# File updated successfully in mahoneyjustinnj/myGarminHealth_JM
