# %% [markdown]
# <a href="https://colab.research.google.com/github/mahoneyjustinnj/myGarminHealth_JM/blob/main/getGarminData260102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install garminconnect
# Out:
# Collecting garminconnect
#   Downloading garminconnect-0.2.38-py3-none-any.whl.metadata (15 kB)
# Collecting garth<0.6.0,>=0.5.17 (from garminconnect)
#   Downloading garth-0.5.20-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: pydantic<3.0.0,>=1.10.12 in /usr/local/lib/python3.12/dist-packages (from garth<0.6.0,>=0.5.17->garminconnect) (2.12.3)
# Requirement already satisfied: requests-oauthlib<3.0.0,>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from garth<0.6.0,>=0.5.17->garminconnect) (2.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from garth<0.6.0,>=0.5.17->garminconnect) (2.32.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=1.10.12->garth<0.6.0,>=0.5.17->garminconnect) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=1.10.12->garth<0.6.0,>=0.5.17->garminconnect) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=1.10.12->garth<0.6.0,>=0.5.17->garminconnect) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=1.10.12->garth<0.6.0,>=0.5.17->garminconnect) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->garth<0.6.0,>=0.5.17->garminconnect) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->garth<0.6.0,>=0.5.17->garminconnect) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->garth<0.6.0,>=0.5.17->garminconnect) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->garth<0.6.0,>=0.5.17->garminconnect) (2025.11.12)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib<3.0.0,>=1.3.1->garth<0.6.0,>=0.5.17->garminconnect) (3.3.1)
# Downloading garminconnect-0.2.38-py3-none-any.whl (32 kB)
# Downloading garth-0.5.20-py3-none-any.whl (33 kB)
# Installing collected packages: garth, garminconnect
# Successfully installed garminconnect-0.2.38 garth-0.5.20

# %%
# command line itself, is written into the file.
# %%writefile cods.py
EMAIL = "???????om"
PASSWORD="????"
# Out:
# Writing cods.py

# %%
#!pip install garminconnect

# This cell uses the `%%writefile` magic command to create a file named `cods.py`
# in the current working directory. The content of this cell, excluding the magic
# command line itself, is written into the file.

from cods import PASSWORD, EMAIL
# print(EMAIL)
# print(PASSWORD)
import garminconnect
#from getpass import getpass
import os
# Define the path you want to set as your working directory
path = "/content"
# Set the working directory
os.chdir(path)
# Confirm it's set correctly
print("Current working directory:", os.getcwd())

print(EMAIL)
print(PASSWORD)

# run locally or in Colab
# pip install garminconnect garth pandas
from datetime import date, timedelta
import pandas as pd
from garminconnect import Garmin

# Login
g = Garmin(email=EMAIL, password=PASSWORD)
g.login()
#check if login succeeds
print(g.garth.profile)

from datetime import date, timedelta
import pandas as pd

# Define the start and end dates
start_date = date(2025, 8, 20)
end_date = date.today()

# Initialize a list to store all daily summaries
all_summaries = []

# Loop through each date
current_date = start_date
while current_date <= end_date:
    try:
        # Get heart rate summary
        hr_summary = g.get_heart_rates(current_date.isoformat())

        # Get HRV data
        hrv_data = g.get_hrv_data(current_date.isoformat())

        # Get respiration data
        respiration_data = g.get_respiration_data(current_date.isoformat())

	# Get respiration data
        sleep_data = g.get_sleep_data(current_date.isoformat())

        # Combine all data into one dictionary
        combined = {
            "summaryDate": current_date.isoformat(),
            **hr_summary,
            **hrv_data,
            **respiration_data,
            **sleep_data
        }

        # Append to the list
        all_summaries.append(combined)

    except Exception as e:
        print(f"Error fetching {current_date}: {e}")

    current_date += timedelta(days=1)

# Convert to DataFrame
df = pd.DataFrame(all_summaries)

# Save to CSV
df.to_csv("garmin_combined_summaries_from_2026-01-06.csv", index=False)

# %% [markdown]
# #Push Garmin data to github

# %%
# Install PyGithub library
#!pip install PyGithub

# %%
# Import necessary libraries
from google.colab import userdata
from github import Github
import pandas as pd
TOKEN = userdata.get('GITHUB_TOKEN')
g = Github(TOKEN)

# %%
# Import necessary libraries
# from github import Github
# import pandas as pd

# Authenticate with GitHub using your personal access token
#g = Github("YOUR_GITHUB_TOKEN")

# Get your repository
repo = g.get_user().get_repo("myGarminHealth_JM")

# Read your CSV file from /content folder
df = pd.read_csv("/content/garmin_combined_summaries_from_2026-01-06.csv")

# Convert dataframe to CSV string
csv_content = df.to_csv(index=False)

# Push to GitHub
git_file = repo.create_file(
    path="rawGarminData.csv",  # Path in repo where file will be saved
    message="Add raw Garmin health data",  # Commit message
    content=csv_content
)

print(f"File pushed successfully to {repo.full_name}")
# Out:
# File pushed successfully to mahoneyjustinnj/myGarminHealth_JM
